# %%
import cv2
import matplotlib.pyplot as plt
import mediapipe as mp

# %%
img=cv2.imread('/home/fasna/Music/bdmay/media_pipe/data/index.jpeg')

# %%
cv2.imshow('image',img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
rgb_img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(rgb_img)

# %%
mp_hands=mp.solutions.hands
hands=mp_hands.Hands(static_image_mode=True,max_num_hands=2,min_detection_confidence=0.3)
mp_drawing=mp.solutions.drawing_utils
# Out:
# I0000 00:00:1704425839.643219    4193 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1704425839.649570    6591 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 21.0.3), renderer: AMD RENOIR (DRM 3.40.0, 5.11.0-27-generic, LLVM 12.0.0)

# %%
results=hands.process(rgb_img)

# %%
print(results.multi_handedness)
# Out:
# [classification {
#   index: 0
#   score: 0.991305947303772
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9894750118255615
#   label: "Right"
# }
# ]

# %%
if results.multi_hand_landmarks:
    for hand_no,hand_landmarks in enumerate(results.multi_hand_landmarks):
        mp_drawing.draw_landmarks(
            image=rgb_img,
            landmark_list=hand_landmarks,
            connections=mp_hands.HAND_CONNECTIONS
        )
plt.imshow(rgb_img)
