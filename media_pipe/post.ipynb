# %%
import cv2
import mediapipe as mp
import matplotlib.pyplot as plt

# %%
img=cv2.imread('/home/fasna/Music/bdmay/media_pipe/data/full_body.jpg')

# %%
rgb_img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(rgb_img)

# %%
mp_pose=mp.solutions.pose
pose=mp_pose.Pose()
mp_drawing=mp.solutions.drawing_utils
# Out:
# I0000 00:00:1704684775.401019    9374 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1704684775.407181    9863 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 21.0.3), renderer: AMD RENOIR (DRM 3.40.0, 5.11.0-27-generic, LLVM 12.0.0)

# %%
results=pose.process(rgb_img)

# %%
if results.pose_landmarks:
    mp_drawing.draw_landmarks(rgb_img,results.pose_landmarks,mp_pose.POSE_CONNECTIONS)
plt.imshow(rgb_img)
