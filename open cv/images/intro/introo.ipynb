# %%
import cv2

# %%
img=cv2.imread('/home/fasna/Music/bdmay/open cv/images/images/c6c164e07772ff2a09866989ac06eedd.jpg')

# %%
img
# Out:
# array([[[ 47,  58, 138],
#         [ 47,  58, 138],
#         [ 47,  58, 138],
#         ...,
#         [ 15,  11,  16],
#         [ 15,  12,  14],
#         [ 15,  12,  14]],
#
#        [[ 47,  58, 138],
#         [ 47,  58, 138],
#         [ 47,  58, 138],
#         ...,
#         [ 15,  11,  16],
#         [ 15,  12,  14],
#         [ 15,  12,  14]],
#
#        [[ 47,  58, 138],
#         [ 47,  58, 138],
#         [ 48,  60, 138],
#         ...,
#         [ 14,  10,  15],
#         [ 14,  11,  13],
#         [ 14,  11,  13]],
#
#        ...,
#
#        [[163, 173, 203],
#         [161, 171, 201],
#         [160, 170, 200],
#         ...,
#         [  6,   6,   6],
#         [  6,   6,   6],
#         [  6,   6,   6]],
#
#        [[162, 172, 202],
#         [161, 171, 201],
#         [159, 169, 199],
#         ...,
#         [  6,   6,   6],
#         [  6,   6,   6],
#         [  6,   6,   6]],
#
#        [[162, 172, 202],
#         [161, 171, 201],
#         [159, 169, 199],
# ...

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
cv2.imshow('image',img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
converted_img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(converted_img)

# %%
grey_img=cv2.imread('/home/fasna/Music/bdmay/open cv/images/images/c6c164e07772ff2a09866989ac06eedd.jpg',cv2.IMREAD_GRAYSCALE)

# %%
cv2.imshow('image',img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
gray_image_converted=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
cv2.imshow('gray img converted',gray_image_converted)
cv2.imshow('image',img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
cv2.imwrite('/home/fasna/Music/bdmay/open cv/converted_img.jpg',gray_image_converted)
# Out:
# True

# %%
#binary image or black and white image
(thresh,img_bw)=cv2.threshold(gray_image_converted,50,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)

# %%
print(thresh)
# Out:
# 90.0

# %%
cv2.imshow('bw image',img_bw)
cv2.waitKey()
cv2.destroyAllWindows()
