# %%
import cv2
img=cv2.imread('/home/fasna/Music/bdmay/open cv/images/images/c6c164e07772ff2a09866989ac06eedd.jpg')

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
img_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
#rectangle
rect_img=cv2.rectangle(img_rgb,pt1=(100,300),pt2=(300,100),color=(255,0,255),thickness=10)
plt.imshow(rect_img)

# %%
img_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
fill_rect=cv2.rectangle(img_rgb,pt1=(100,500),pt2=(200,400),color=(255,255,0),thickness=-1)
fill_rect=cv2.rectangle(img_rgb,pt1=(200,500),pt2=(300,400),color=(0,255,0),thickness=-1)
fill_rect=cv2.rectangle(img_rgb,pt1=(0,500),pt2=(100,400),color=(128,0,128),thickness=-1)
plt.imshow(fill_rect)

# %%
#Circle
img_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
cir_img=cv2.circle(img_rgb,center=(140,170),radius=100,color=(255,0,0),thickness=5)
plt.imshow(cir_img)

# %%
img_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
rec_img1=cv2.rectangle(img_rgb,pt1=(25,250),pt2=(320,100),color=(0,0,0),thickness=-1)
cir_img1=cv2.circle(img_rgb,center=(90,170),radius=60,color=(255,255,0),thickness=-1)
cir_img1=cv2.circle(img_rgb,center=(140,170),radius=60,color=(255,0,0),thickness=-1)
cir_img1=cv2.circle(img_rgb,center=(200,170),radius=60,color=(255,0,255),thickness=-1)
cir_img1=cv2.circle(img_rgb,center=(260,170),radius=60,color=(0,0,255),thickness=-1)

plt.imshow(cir_img1)

# %%
img_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
rec_img2=cv2.rectangle(img_rgb,pt1=(25,250),pt2=(320,100),color=(0,0,0),thickness=-1)
cir1=cv2.circle(img_rgb,center=(90,170),radius=60,color=(0,0,255),thickness=3)
cir1=cv2.circle(img_rgb,center=(180,170),radius=60,color=(255,0,255),thickness=3)
cir1=cv2.circle(img_rgb,center=(270,170),radius=60,color=(0,255,255),thickness=3)
plt.imshow(cir1)

# %%
img_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
text_img=cv2.putText(img_rgb,
                     text='pinto',
                     org=(350,600),
                     fontFace=cv2.FONT_HERSHEY_PLAIN,
                     fontScale=2,
                     color=(0,0,250),
                     thickness=4)
plt.imshow(text_img)

# %%
img_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
rec_img2=cv2.rectangle(img_rgb,pt1=(100,500),pt2=(545,700),color=(255,255,0),thickness=-1)
text_img=cv2.putText(img_rgb,
                     text='pinto',
                     org=(130,610),
                     fontFace=cv2.FONT_HERSHEY_COMPLEX,
                     fontScale=2.5,
                     color=(0,0,250),
                     thickness=4)
cir1=cv2.circle(img_rgb,center=(450,600),radius=100,color=(0,255,255),thickness=-1)
plt.imshow(text_img)
